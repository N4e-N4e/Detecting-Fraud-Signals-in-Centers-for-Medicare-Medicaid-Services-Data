# %% [markdown]
# # Supervised ML PipeLine Template
#
# This notebook contains a comprehensive ML pipeline template for the following model:
# 2) XGBoost
#
# Additonally, the follow undersample methods can be chosen:
# 1) RandomUnderSampler
#
# ### Some of the assumptions:
# 1) Data is pre-cleaned with no missing values.
# 2) Only numeric features are used as all other columns are excluded automatically.
#
# ## How will this be used (steps):
# 1) Only run in new notebooks, import the module as follows: **from Supervised_ML_Pipeline import MLPipeline**
# 2) Declare an object and initialize it as follows: **pipe = MLPipeline(model_name="svm", target_col="outcome")**
# 3) This line does the data spliting, training & testing and provides results: **pipe.run(df, param_grid={}, group_col="", exclude_cols=[], undersample_method=None)**
#
# Important - Read the below parameters
#
# #### Required parameters:
# 1) model_name - can't run without knowing which model
# 2) target_col - can't extract features without knowing the target
# 3) param_grid - can't run GridSearchCV without parameters
# 4) group_col - can't do StratifiedGroupKFold without groups
#
# #### Optional parameters:
# 1) exclude_cols - defaults to [] if not passed, pipeline still runs fine
# 2) undersample_method - defaults to None, no undersampling applied
# 3) output_dir - defaults to ".", saves in current directory
# 4) cv, scoring, test_size, random_state, verbose - all have sensible defaults (5, average_precision, 0.4, 42, 1)
#
# #### Additional stuff:
# 1) list_models() gives a list of models available
# 2) list_undersample_methods() gives a list of undersampling methods available
#
# ## Results:
# 1) Displays a quick summary of the training along with evaluation metrics conducted on test data.
# 2) Saves a score distrution plot and confusion matrix plot as png.
# 3) Saves a csv file with test scores and their respective risk label.
# 4) Saves a summary, waterfall and feature importance plot as png (SHAP).

# %%
# In the Libraries portion of a new different notebook
from Supervised_ML_Pipeline import MLPipeline
import pandas as pd

# %%
MLPipeline.list_models()
# Out:
# ['logistic_regression', 'xgboost', 'svm']

# %%
MLPipeline.list_undersample_methods()
# Out:
# ['RandomUnderSampler', 'CLEANSE']

# %%
MLPipeline.list_feature_selection_methods()
# Out:
# ['k_best_catboost', 'k_best_xgb', 'k_best_lgbm', 'k_best_decision_tree']

# %%
select_methods = MLPipeline.list_feature_selection_methods()
select_methods
# Out:
# ['k_best_catboost', 'k_best_xgb', 'k_best_lgbm', 'k_best_decision_tree']

# %%
df = pd.read_csv("/dsa/groups/casestudycf25/team02/silver/unified_dme_year_npi_hcpcs_rentl_ind_labeled.csv")

target_col = 'target'

exclude_cols = [
    'npi', 'rfrg_prvdr_state_abrvtn',
    'specialty_type', 'specialty'
]

df.head(5)
# Out:
#           npi hcpcs_cd  suplr_rentl_ind  tot_suplrs  tot_suplr_benes  \
# 0  1003000902    A4253                0          11             14.0
# 1  1003000902    A4259                0           8              5.0
# 2  1003000902    A4390                0           3              5.0
# 3  1003000902    E0570                1           1              5.0
# 4  1003000902    E1390                1           2              5.0
#
#    tot_suplr_clms  tot_suplr_srvcs  avg_suplr_sbmtd_chrg  \
# 0              32               67             68.483134
# 1              14               17             14.727647
# 2              17              330             16.484364
# 3              12               12             50.730000
# 4              24               24            389.755000
#
#    avg_suplr_mdcr_alowd_amt  year  ...  claims_per_bene_zscore_by_type  \
# 0                  8.386567  2021  ...                             0.0
# 1                  1.437647  2021  ...                             0.0
# 2                 11.178182  2021  ...                             0.0
# 3                  5.921667  2021  ...                             0.0
# 4                111.531667  2021  ...                             0.0
#
#    claims_per_bene_outlier_by_type  services_per_bene_zscore  \
# 0                            False                       0.0
# 1                            False                       0.0
# 2                            False                       0.0
# 3                            False                       0.0
# 4                            False                       0.0
#
#    services_per_bene_outlier  services_per_bene_zscore_by_type  \
# 0                      False                               0.0
# 1                      False                               0.0
# 2                      False                               0.0
# 3                      False                               0.0
# 4                      False                               0.0
#
#    services_per_bene_outlier_by_type  benes_per_supplier_zscore  \
# 0                              False                        0.0
# 1                              False                        0.0
# 2                              False                        0.0
# 3                              False                        0.0
# 4                              False                        0.0
#
#    benes_per_supplier_outlier  benes_per_supplier_zscore_by_type  \
# 0                       False                                0.0
# 1                       False                                0.0
# 2                       False                                0.0
# 3                       False                                0.0
# 4                       False                                0.0
#
#    benes_per_supplier_outlier_by_type
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
# [5 rows x 156 columns]

# %%
df.columns.to_list()
# Out:
# ['npi',
#  'hcpcs_cd',
#  'suplr_rentl_ind',
#  'tot_suplrs',
#  'tot_suplr_benes',
#  'tot_suplr_clms',
#  'tot_suplr_srvcs',
#  'avg_suplr_sbmtd_chrg',
#  'avg_suplr_mdcr_alowd_amt',
#  'year',
#  'tot_suplr_mdcr_pymt_amt',
#  'tot_suplr_mdcr_pymt_amt_hcpcs_rentl_ind_z_scr',
#  'avg_suplr_mdcr_alowd_amt_hcpcs_rentl_ind_rat',
#  'target',
#  'n_manufacturing_entities',
#  'total_payment',
#  'third_party_equals_covered_recipient_indicator',
#  'covered_biological',
#  'covered_device',
#  'covered_drug',
#  'covered_medical supply',
#  'non-covered_device',
#  'non-covered_drug',
#  'non-covered_medical supply',
#  'is_weekend_payment',
#  'is_q4_payment',
#  'dme_urological_supplies',
#  'dme_surgical_dressings',
#  'dme_lower_limb_orthotics',
#  'dme_parenteral_nutrition',
#  'dme_ventilators',
#  'dme_oxygen_accessories',
#  'dme_oxygen_equipment',
#  'dme_humidifiers_and_nebulizers',
#  'dme_wheelchair_access',
#  'dme_pharmacy_dispensing',
#  'dme_infusion_pumps',
#  'dme_breathing_aids',
#  'dme_hospital_beds',
#  'dme_replacement_batteries',
#  'dme_tapes_and_medical_supplies',
#  'n_cities',
#  'n_countries',
#  'form_count_cash_or_cash_equivalent',
#  'form_count_dividend_profit_or_other_return_on_investment',
#  'form_count_in_kind_items_and_services',
#  'form_count_stock_stock_option_or_any_other_ownership_interest',
#  'form_sum_dividend_profit_or_other_return_on_investment',
#  'form_sum_in_kind_items_and_services',
#  'form_sum_stock',
#  'form_sum_stock_stock_option_or_any_other_ownership_interest',
#  'third_party_recipient_count_entity',
#  'third_party_recipient_count_individual',
#  'third_party_recipient_sum_entity',
#  'third_party_recipient_sum_individual',
#  'third_party_recipient_sum_no_third_party_payment',
#  'nature_count_acquisition',
#  'nature_count_consulting',
#  'nature_count_debt_forgiveness',
#  'nature_count_education',
#  'nature_count_entertainment',
#  'nature_count_faculty_or_speaker',
#  'nature_count_other_services',
#  'nature_sum_acquisition',
#  'nature_sum_consulting',
#  'nature_sum_debt_forgiveness',
#  'nature_sum_entertainment',
#  'nature_sum_faculty_or_speaker',
#  'nature_sum_food_and_beverage',
#  'nature_sum_other_services',
#  'nature_sum_ownership_or_investment',
#  'n_third_party_entities',
#  'total_invested_usd',
#  'total_value_of_interest',
#  'immediate_family_member',
#  'physician_covered_recipient',
#  'specialty_type',
#  'specialty',
#  'specialty_lvl1_Agencies',
#  'specialty_lvl1_Allopathic & Osteopathic Physicians',
#  'specialty_lvl1_Behavioral Health & Social Service Providers',
#  'specialty_lvl1_Dental Providers',
#  'specialty_lvl1_Eye and Vision Services Providers',
#  'specialty_lvl1_Nursing Service Providers',
#  'specialty_lvl1_Other Service Providers',
#  'specialty_lvl1_Pharmacy Service Providers',
#  'specialty_lvl1_Physician Assistants & Advanced Practice Nursing Providers',
#  'specialty_lvl1_Podiatric Medicine & Surgery Service Providers',
#  'specialty_lvl1_Student',
#  'active_medicaid_provider_flag',
#  'submitted_charge_per_bene',
#  'submitted_charge_per_bene_missing_flag',
#  'submitted_charge_per_bene_num_missing_flag',
#  'submitted_charge_per_bene_den_missing_flag',
#  'submitted_charge_per_bene_den_zero_flag',
#  'submitted_to_standardized_ratio',
#  'submitted_to_standardized_ratio_missing_flag',
#  'submitted_to_standardized_ratio_num_missing_flag',
#  'submitted_to_standardized_ratio_den_missing_flag',
#  'submitted_to_standardized_ratio_den_zero_flag',
#  'claims_per_bene',
#  'claims_per_bene_missing_flag',
#  'claims_per_bene_num_missing_flag',
#  'claims_per_bene_den_missing_flag',
#  'claims_per_bene_den_zero_flag',
#  'services_per_bene',
#  'services_per_bene_missing_flag',
#  'services_per_bene_num_missing_flag',
#  'services_per_bene_den_missing_flag',
#  'services_per_bene_den_zero_flag',
#  'benes_per_supplier',
#  'benes_per_supplier_missing_flag',
#  'benes_per_supplier_num_missing_flag',
#  'benes_per_supplier_den_missing_flag',
#  'benes_per_supplier_den_zero_flag',
#  'dme_glucose_monitors_pctile',
#  'dme_positive_airway_pctile_by_type',
#  'total_payment_pctile_by_type',
#  'submitted_charge_per_bene_pctile',
#  'submitted_charge_per_bene_pctile_by_type',
#  'submitted_to_standardized_ratio_pctile',
#  'claims_per_bene_pctile',
#  'services_per_bene_pctile',
#  'benes_per_supplier_pctile',
#  'dme_glucose_monitors_outlier',
#  'dme_glucose_monitors_zscore_by_type',
#  'dme_glucose_monitors_outlier_by_type',
#  'dme_positive_airway_outlier',
#  'dme_positive_airway_zscore_by_type',
#  'dme_positive_airway_outlier_by_type',
#  'dme_diabetes_supplies_and_contraceptives_outlier',
#  'dme_diabetes_supplies_and_contraceptives_zscore_by_type',
#  'dme_diabetes_supplies_and_contraceptives_outlier_by_type',
#  'total_payment_outlier',
#  'total_payment_zscore_by_type',
#  'total_payment_outlier_by_type',
#  'submitted_charge_per_bene_zscore',
#  'submitted_charge_per_bene_outlier',
#  'submitted_charge_per_bene_zscore_by_type',
#  'submitted_charge_per_bene_outlier_by_type',
#  'submitted_to_standardized_ratio_zscore',
#  'submitted_to_standardized_ratio_outlier',
#  'submitted_to_standardized_ratio_zscore_by_type',
#  'submitted_to_standardized_ratio_outlier_by_type',
#  'claims_per_bene_zscore',
#  'claims_per_bene_outlier',
#  'claims_per_bene_zscore_by_type',
#  'claims_per_bene_outlier_by_type',
#  'services_per_bene_zscore',
#  'services_per_bene_outlier',
#  'services_per_bene_zscore_by_type',
#  'services_per_bene_outlier_by_type',
#  'benes_per_supplier_zscore',
#  'benes_per_supplier_outlier',
#  'benes_per_supplier_zscore_by_type',
#  'benes_per_supplier_outlier_by_type']

# %%
param_grid = {
    "model__C": [0.001, 0.1, 1, 10],
    "model__penalty": ["l1", "l2", "elasticnet"],
    "model__solver": ["saga"],
    "model__l1_ratio": [0.5, 0, 1.0],
    "model__max_iter": [500],
    "model__class_weight": ["balanced", {1: 250}, {1: 1500}],
    "selector__k": [25]
}

# %%
###########################
# RUN HISTORY
############################

###### RUN 1
# No INNE, Cleanse, every different feature selection method.
# param_grid = {
#     "model__C": [0.001, 0.1, 1, 10],
#     "model__penalty": ["l1", "l2", "elasticnet"],
#     "model__solver": ["saga"],
#     "model__l1_ratio": [0.5, 0, 1.0],
#     "model__max_iter": [500],
#     "model__class_weight": ["balanced", {1: 250}, {1: 1500}],
#     "selector__k": [10,25,50]
# }

# %%
pipe = MLPipeline(model_name="logistic_regression", target_col=target_col)

# %%
for feature_selection_m in select_methods:
    print(f"\n{'='*60}")
    print(f"Running with feature_selection_method: {feature_selection_m}")
    print(f"{'='*60}\n")

    #420000 secs
    pipe.train(df, 
               param_grid=param_grid, 
               group_col="npi", 
               exclude_cols=exclude_cols, 
               undersample_method='CLEANSE', 
               feature_selection_method=feature_selection_m)
# Out:
# ============================================================
# Running with feature_selection_method: k_best_catboost
# ============================================================
#
#
# Undersampling (CLEANSE) applied.
# Class distribution after undersampling: {0: 406983, 1: 234}
#
# Feature Selection (k_best_catboost) selected.
#   Fold 1 validation prevalence (baseline AUPRC): 0.0006
#   Fold 2 validation prevalence (baseline AUPRC): 0.0007
#   Fold 3 validation prevalence (baseline AUPRC): 0.0005
#   Fold 4 validation prevalence (baseline AUPRC): 0.0005
#   Fold 5 validation prevalence (baseline AUPRC): 0.0005
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 3/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.475) precision_macro: (test=0.501) recall_macro: (test=0.594) roc_auc: (test=0.609) total time= 2.6min
# [CV 1/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.479) precision_macro: (test=0.500) recall_macro: (test=0.472) roc_auc: (test=0.634) total time= 2.6min
# [CV 4/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.445) precision_macro: (test=0.500) recall_macro: (test=0.459) roc_auc: (test=0.257) total time= 2.7min
# [CV 3/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.475) precision_macro: (test=0.501) recall_macro: (test=0.594) roc_auc: (test=0.609) total time= 2.7min
# [CV 1/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.478) precision_macro: (test=0.500) recall_macro: (test=0.469) roc_auc: (test=0.627) total time= 1.7min
# [CV 1/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.479) precision_macro: (test=0.500) recall_macro: (test=0.493) roc_auc: (test=0.650) total time= 3.1min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.499) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.372) total time= 2.9min
# [CV 3/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.006) f1_macro: (test=0.507) precision_macro: (test=0.505) recall_macro: (test=0.579) roc_auc: (test=0.565) total time= 2.9min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.666) total time= 1.5min
# [CV 3/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.006) f1_macro: (test=0.506) precision_macro: (test=0.504) recall_macro: (test=0.579) roc_auc: (test=0.564) total time= 2.6min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.666) total time= 1.6min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.699) total time= 3.0min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.452) precision_macro: (test=0.500) recall_macro: (test=0.470) roc_auc: (test=0.256) total time= 3.0min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.481) precision_macro: (test=0.500) recall_macro: (test=0.475) roc_auc: (test=0.442) total time= 2.4min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.485) precision_macro: (test=0.500) recall_macro: (test=0.470) roc_auc: (test=0.614) total time= 1.3min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.091) f1_macro: (test=0.466) precision_macro: (test=0.501) recall_macro: (test=0.706) roc_auc: (test=0.815) total time= 2.1min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.480) precision_macro: (test=0.500) recall_macro: (test=0.474) roc_auc: (test=0.465) total time= 2.5min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.452) precision_macro: (test=0.500) recall_macro: (test=0.470) roc_auc: (test=0.256) total time= 2.6min
# [CV 2/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.100) f1_macro: (test=0.444) precision_macro: (test=0.501) recall_macro: (test=0.679) roc_auc: (test=0.808) total time= 2.6min
# [CV 4/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.445) precision_macro: (test=0.500) recall_macro: (test=0.470) roc_auc: (test=0.254) total time= 2.7min
# [CV 2/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.100) f1_macro: (test=0.444) precision_macro: (test=0.501) recall_macro: (test=0.679) roc_auc: (test=0.808) total time= 2.5min
# [CV 4/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.445) precision_macro: (test=0.500) recall_macro: (test=0.470) roc_auc: (test=0.254) total time= 2.5min
# [CV 2/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.100) f1_macro: (test=0.444) precision_macro: (test=0.501) recall_macro: (test=0.679) roc_auc: (test=0.808) total time= 2.4min
# [CV 5/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.472) precision_macro: (test=0.500) recall_macro: (test=0.482) roc_auc: (test=0.454) total time= 2.6min
# [CV 3/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.005) f1_macro: (test=0.506) precision_macro: (test=0.504) recall_macro: (test=0.578) roc_auc: (test=0.579) total time= 2.7min
# [CV 1/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.639) total time= 2.8min
# [CV 5/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.372) total time= 2.4min
# [CV 2/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.091) f1_macro: (test=0.445) precision_macro: (test=0.501) recall_macro: (test=0.698) roc_auc: (test=0.804) total time= 2.5min
# [CV 5/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.477) precision_macro: (test=0.500) recall_macro: (test=0.467) roc_auc: (test=0.420) total time= 2.1min
# [CV 3/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.474) precision_macro: (test=0.501) recall_macro: (test=0.591) roc_auc: (test=0.624) total time= 2.9min
# [CV 2/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.091) f1_macro: (test=0.445) precision_macro: (test=0.501) recall_macro: (test=0.698) roc_auc: (test=0.804) total time= 2.6min
# [CV 5/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.479) precision_macro: (test=0.500) recall_macro: (test=0.471) roc_auc: (test=0.435) total time= 3.6min
# [CV 5/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.479) precision_macro: (test=0.500) recall_macro: (test=0.471) roc_auc: (test=0.435) total time= 2.8min
# [CV 3/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.006) f1_macro: (test=0.506) precision_macro: (test=0.504) recall_macro: (test=0.579) roc_auc: (test=0.564) total time= 2.5min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.039) f1_macro: (test=0.558) precision_macro: (test=0.538) recall_macro: (test=0.632) roc_auc: (test=0.902) total time= 2.7min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.495) roc_auc: (test=0.347) total time= 2.1min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.039) f1_macro: (test=0.558) precision_macro: (test=0.538) recall_macro: (test=0.632) roc_auc: (test=0.902) total time= 2.9min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.495) roc_auc: (test=0.347) total time= 2.2min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.091) f1_macro: (test=0.461) precision_macro: (test=0.501) recall_macro: (test=0.706) roc_auc: (test=0.849) total time= 2.4min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.453) precision_macro: (test=0.500) recall_macro: (test=0.472) roc_auc: (test=0.241) total time= 2.1min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.091) f1_macro: (test=0.461) precision_macro: (test=0.501) recall_macro: (test=0.706) roc_auc: (test=0.849) total time= 2.6min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.481) precision_macro: (test=0.500) recall_macro: (test=0.474) roc_auc: (test=0.425) total time= 1.8min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.091) f1_macro: (test=0.461) precision_macro: (test=0.501) recall_macro: (test=0.706) roc_auc: (test=0.849) total time= 2.6min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.481) precision_macro: (test=0.500) recall_macro: (test=0.474) roc_auc: (test=0.425) total time= 1.7min
# [CV 2/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.100) f1_macro: (test=0.444) precision_macro: (test=0.501) recall_macro: (test=0.679) roc_auc: (test=0.808) total time= 2.8min
# [CV 5/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.473) precision_macro: (test=0.500) recall_macro: (test=0.482) roc_auc: (test=0.452) total time= 2.4min
# [CV 3/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.473) precision_macro: (test=0.500) recall_macro: (test=0.589) roc_auc: (test=0.638) total time= 2.7min
# [CV 1/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.476) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.547) total time= 2.4min
# [CV 4/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.445) precision_macro: (test=0.500) recall_macro: (test=0.469) roc_auc: (test=0.254) total time= 2.6min
# [CV 1/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.475) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.546) total time= 2.7min
# [CV 4/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.250) total time= 2.6min
# [CV 2/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.073) f1_macro: (test=0.591) precision_macro: (test=0.556) recall_macro: (test=0.757) roc_auc: (test=0.859) total time= 2.6min
# [CV 5/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.373) total time= 2.7min
# [CV 3/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.005) f1_macro: (test=0.506) precision_macro: (test=0.504) recall_macro: (test=0.578) roc_auc: (test=0.579) total time= 2.5min
# [CV 5/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.479) precision_macro: (test=0.500) recall_macro: (test=0.471) roc_auc: (test=0.435) total time= 3.0min
# [CV 1/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.479) precision_macro: (test=0.500) recall_macro: (test=0.493) roc_auc: (test=0.650) total time= 2.5min
# [CV 5/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.479) precision_macro: (test=0.500) recall_macro: (test=0.471) roc_auc: (test=0.435) total time= 2.7min
# [CV 1/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.479) precision_macro: (test=0.500) recall_macro: (test=0.493) roc_auc: (test=0.650) total time= 2.8min
# [CV 4/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.443) precision_macro: (test=0.500) recall_macro: (test=0.467) roc_auc: (test=0.235) total time= 2.7min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.699) total time= 2.9min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.266) total time= 2.5min
# [CV 3/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.005) f1_macro: (test=0.508) precision_macro: (test=0.505) recall_macro: (test=0.579) roc_auc: (test=0.575) total time= 2.7min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.666) total time= 1.5min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.266) total time= 2.4min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.064) f1_macro: (test=0.603) precision_macro: (test=0.564) recall_macro: (test=0.757) roc_auc: (test=0.855) total time= 2.7min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.495) roc_auc: (test=0.399) total time= 2.8min
# [CV 3/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.480) precision_macro: (test=0.501) recall_macro: (test=0.590) roc_auc: (test=0.616) total time= 2.4min
# [CV 3/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.475) precision_macro: (test=0.501) recall_macro: (test=0.593) roc_auc: (test=0.641) total time= 2.8min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.485) precision_macro: (test=0.500) recall_macro: (test=0.470) roc_auc: (test=0.614) total time= 1.3min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.481) precision_macro: (test=0.500) recall_macro: (test=0.474) roc_auc: (test=0.425) total time= 2.0min
# [CV 3/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.480) precision_macro: (test=0.501) recall_macro: (test=0.590) roc_auc: (test=0.616) total time= 2.3min
# [CV 1/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.475) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.546) total time= 2.8min
# [CV 4/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.445) precision_macro: (test=0.500) recall_macro: (test=0.470) roc_auc: (test=0.254) total time= 2.4min
# [CV 2/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.100) f1_macro: (test=0.444) precision_macro: (test=0.501) recall_macro: (test=0.679) roc_auc: (test=0.808) total time= 2.6min
# [CV 5/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.473) precision_macro: (test=0.500) recall_macro: (test=0.482) roc_auc: (test=0.452) total time= 2.4min
# [CV 3/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.473) precision_macro: (test=0.500) recall_macro: (test=0.589) roc_auc: (test=0.638) total time= 2.8min
# [CV 2/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.100) f1_macro: (test=0.444) precision_macro: (test=0.501) recall_macro: (test=0.679) roc_auc: (test=0.808) total time= 2.8min
# [CV 5/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.373) total time= 2.7min
# [CV 3/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.005) f1_macro: (test=0.506) precision_macro: (test=0.504) recall_macro: (test=0.578) roc_auc: (test=0.579) total time= 2.8min
# [CV 1/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.639) total time= 2.5min
# [CV 4/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.249) total time= 2.4min
# [CV 2/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.086) f1_macro: (test=0.447) precision_macro: (test=0.501) recall_macro: (test=0.709) roc_auc: (test=0.859) total time= 3.0min
# [CV 5/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.478) precision_macro: (test=0.500) recall_macro: (test=0.469) roc_auc: (test=0.424) total time= 2.9min
# [CV 4/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.443) precision_macro: (test=0.500) recall_macro: (test=0.467) roc_auc: (test=0.235) total time= 2.4min
# [CV 5/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.477) precision_macro: (test=0.500) recall_macro: (test=0.467) roc_auc: (test=0.420) total time= 2.2min
# [CV 2/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.091) f1_macro: (test=0.445) precision_macro: (test=0.501) recall_macro: (test=0.698) roc_auc: (test=0.804) total time= 3.0min
# [CV 4/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.445) precision_macro: (test=0.500) recall_macro: (test=0.459) roc_auc: (test=0.257) total time= 2.8min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.064) f1_macro: (test=0.603) precision_macro: (test=0.564) recall_macro: (test=0.757) roc_auc: (test=0.855) total time= 2.4min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.362) total time= 3.0min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.266) total time= 2.6min
# [CV 3/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.005) f1_macro: (test=0.508) precision_macro: (test=0.505) recall_macro: (test=0.579) roc_auc: (test=0.575) total time= 2.9min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.039) f1_macro: (test=0.558) precision_macro: (test=0.538) recall_macro: (test=0.632) roc_auc: (test=0.902) total time= 2.7min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.480) precision_macro: (test=0.500) recall_macro: (test=0.474) roc_auc: (test=0.465) total time= 2.7min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.453) precision_macro: (test=0.500) recall_macro: (test=0.472) roc_auc: (test=0.246) total time= 2.6min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.091) f1_macro: (test=0.466) precision_macro: (test=0.501) recall_macro: (test=0.706) roc_auc: (test=0.815) total time= 2.2min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.453) precision_macro: (test=0.500) recall_macro: (test=0.472) roc_auc: (test=0.241) total time= 1.9min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.485) precision_macro: (test=0.500) recall_macro: (test=0.470) roc_auc: (test=0.614) total time= 1.2min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.453) precision_macro: (test=0.500) recall_macro: (test=0.472) roc_auc: (test=0.241) total time= 2.1min
# [CV 3/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.473) precision_macro: (test=0.500) recall_macro: (test=0.589) roc_auc: (test=0.638) total time= 2.6min
# [CV 1/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.475) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.546) total time= 2.6min
# [CV 4/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.445) precision_macro: (test=0.500) recall_macro: (test=0.469) roc_auc: (test=0.254) total time= 2.6min
# [CV 2/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.100) f1_macro: (test=0.444) precision_macro: (test=0.501) recall_macro: (test=0.679) roc_auc: (test=0.808) total time= 2.5min
# [CV 5/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.472) precision_macro: (test=0.500) recall_macro: (test=0.482) roc_auc: (test=0.454) total time= 2.7min
# [CV 3/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.473) precision_macro: (test=0.500) recall_macro: (test=0.589) roc_auc: (test=0.638) total time= 2.7min
# [CV 1/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.639) total time= 2.4min
# [CV 4/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.249) total time= 2.7min
# [CV 2/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.073) f1_macro: (test=0.591) precision_macro: (test=0.556) recall_macro: (test=0.757) roc_auc: (test=0.859) total time= 2.4min
# [CV 5/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.372) total time= 2.6min
# [CV 1/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.478) precision_macro: (test=0.500) recall_macro: (test=0.469) roc_auc: (test=0.627) total time= 1.8min
# [CV 4/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.443) precision_macro: (test=0.500) recall_macro: (test=0.467) roc_auc: (test=0.235) total time= 2.4min
# [CV 2/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.086) f1_macro: (test=0.447) precision_macro: (test=0.501) recall_macro: (test=0.709) roc_auc: (test=0.859) total time= 3.0min
# [CV 5/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.477) precision_macro: (test=0.500) recall_macro: (test=0.467) roc_auc: (test=0.420) total time= 2.5min
# [CV 4/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.445) precision_macro: (test=0.500) recall_macro: (test=0.459) roc_auc: (test=0.257) total time= 3.1min
# [CV 2/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.086) f1_macro: (test=0.447) precision_macro: (test=0.501) recall_macro: (test=0.709) roc_auc: (test=0.859) total time= 3.0min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.495) roc_auc: (test=0.399) total time= 2.7min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.499) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.309) total time= 2.8min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.064) f1_macro: (test=0.603) precision_macro: (test=0.564) recall_macro: (test=0.757) roc_auc: (test=0.855) total time= 2.6min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.495) roc_auc: (test=0.347) total time= 2.3min
# [CV 3/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.006) f1_macro: (test=0.506) precision_macro: (test=0.504) recall_macro: (test=0.579) roc_auc: (test=0.564) total time= 2.6min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.483) precision_macro: (test=0.500) recall_macro: (test=0.499) roc_auc: (test=0.621) total time= 2.7min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.481) precision_macro: (test=0.500) recall_macro: (test=0.474) roc_auc: (test=0.425) total time= 1.8min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.483) precision_macro: (test=0.500) recall_macro: (test=0.499) roc_auc: (test=0.621) total time= 2.8min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.453) precision_macro: (test=0.500) recall_macro: (test=0.472) roc_auc: (test=0.241) total time= 1.9min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.483) precision_macro: (test=0.500) recall_macro: (test=0.499) roc_auc: (test=0.621) total time= 2.8min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.483) precision_macro: (test=0.500) recall_macro: (test=0.499) roc_auc: (test=0.621) total time= 2.8min
# [CV 4/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.445) precision_macro: (test=0.500) recall_macro: (test=0.469) roc_auc: (test=0.254) total time= 2.7min
# [CV 2/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.100) f1_macro: (test=0.444) precision_macro: (test=0.501) recall_macro: (test=0.679) roc_auc: (test=0.808) total time= 2.6min
# [CV 5/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.472) precision_macro: (test=0.500) recall_macro: (test=0.482) roc_auc: (test=0.454) total time= 2.7min
# [CV 3/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.473) precision_macro: (test=0.500) recall_macro: (test=0.589) roc_auc: (test=0.637) total time= 2.4min
# [CV 1/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.476) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.547) total time= 2.5min
# [CV 4/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.445) precision_macro: (test=0.500) recall_macro: (test=0.469) roc_auc: (test=0.254) total time= 2.7min
# [CV 2/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.073) f1_macro: (test=0.591) precision_macro: (test=0.556) recall_macro: (test=0.757) roc_auc: (test=0.859) total time= 2.4min
# [CV 5/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.372) total time= 2.6min
# [CV 3/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.005) f1_macro: (test=0.506) precision_macro: (test=0.504) recall_macro: (test=0.578) roc_auc: (test=0.579) total time= 2.4min
# [CV 1/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.639) total time= 2.6min
# [CV 3/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.474) precision_macro: (test=0.501) recall_macro: (test=0.591) roc_auc: (test=0.624) total time= 2.8min
# [CV 3/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.476) precision_macro: (test=0.501) recall_macro: (test=0.605) roc_auc: (test=0.613) total time= 2.9min
# [CV 2/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.091) f1_macro: (test=0.445) precision_macro: (test=0.501) recall_macro: (test=0.698) roc_auc: (test=0.804) total time= 2.5min
# [CV 4/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.443) precision_macro: (test=0.500) recall_macro: (test=0.467) roc_auc: (test=0.235) total time= 2.5min
# [CV 3/5] END model__C=0.001, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.475) precision_macro: (test=0.501) recall_macro: (test=0.594) roc_auc: (test=0.609) total time= 3.4min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.039) f1_macro: (test=0.558) precision_macro: (test=0.538) recall_macro: (test=0.632) roc_auc: (test=0.902) total time= 2.9min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.495) roc_auc: (test=0.347) total time= 2.0min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.699) total time= 2.8min
# [CV 3/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.006) f1_macro: (test=0.506) precision_macro: (test=0.504) recall_macro: (test=0.579) roc_auc: (test=0.564) total time= 2.6min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.499) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.372) total time= 3.2min
# [CV 3/5] END model__C=0.001, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.005) f1_macro: (test=0.508) precision_macro: (test=0.505) recall_macro: (test=0.579) roc_auc: (test=0.575) total time= 2.7min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.485) precision_macro: (test=0.500) recall_macro: (test=0.470) roc_auc: (test=0.614) total time= 1.3min
# [CV 1/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.485) precision_macro: (test=0.500) recall_macro: (test=0.481) roc_auc: (test=0.614) total time= 2.8min
# [CV 4/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.452) precision_macro: (test=0.500) recall_macro: (test=0.470) roc_auc: (test=0.256) total time= 2.8min
# [CV 3/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.480) precision_macro: (test=0.501) recall_macro: (test=0.590) roc_auc: (test=0.616) total time= 2.3min
# [CV 2/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.091) f1_macro: (test=0.466) precision_macro: (test=0.501) recall_macro: (test=0.706) roc_auc: (test=0.815) total time= 2.2min
# [CV 5/5] END model__C=0.001, model__class_weight={1: 1500}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=elasticnet, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.480) precision_macro: (test=0.500) recall_macro: (test=0.474) roc_auc: (test=0.465) total time= 2.9min
# [CV 3/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.007) f1_macro: (test=0.473) precision_macro: (test=0.500) recall_macro: (test=0.589) roc_auc: (test=0.637) total time= 2.6min
# [CV 1/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.001) f1_macro: (test=0.475) precision_macro: (test=0.500) recall_macro: (test=0.497) roc_auc: (test=0.546) total time= 2.5min
# [CV 4/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.445) precision_macro: (test=0.500) recall_macro: (test=0.470) roc_auc: (test=0.254) total time= 2.4min
# [CV 2/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.100) f1_macro: (test=0.444) precision_macro: (test=0.501) recall_macro: (test=0.679) roc_auc: (test=0.808) total time= 2.7min
# [CV 4/5] END model__C=0.1, model__class_weight=balanced, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.445) precision_macro: (test=0.500) recall_macro: (test=0.470) roc_auc: (test=0.254) total time= 2.4min
# [CV 2/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.073) f1_macro: (test=0.591) precision_macro: (test=0.556) recall_macro: (test=0.757) roc_auc: (test=0.859) total time= 2.5min
# [CV 5/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0.5, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.372) total time= 2.3min
# [CV 2/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.073) f1_macro: (test=0.591) precision_macro: (test=0.556) recall_macro: (test=0.757) roc_auc: (test=0.859) total time= 2.7min
# [CV 4/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=0, model__max_iter=500, model__penalty=l2, model__solver=saga, selector__k=25; auprc: (test=0.000) f1_macro: (test=0.498) precision_macro: (test=0.500) recall_macro: (test=0.496) roc_auc: (test=0.249) total time= 2.4min
# [CV 2/5] END model__C=0.1, model__class_weight={1: 250}, model__l1_ratio=1.0, model__max_iter=500, model__penalty=l1, model__solver=saga, selector__k=25; auprc: (test=0.073) f1_macro: (test=0.591) precision_macro: (test=0.556) recall_macro: (test=0.757) roc_auc: (test=0.859) total time= 3.1min
